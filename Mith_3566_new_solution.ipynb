# %% [markdown]
# # The New Approach (Merging Rows Approch)

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn.preprocessing import LabelEncoder
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import classification_report
from sklearn.ensemble import RandomForestClassifier
from imblearn.over_sampling import RandomOverSampler
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import GradientBoostingClassifier
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import RandomizedSearchCV
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Reading the Data

# %%
train_data = pd.read_csv("train_data.csv", na_values=[" ","?","#"])
test_data = pd.read_csv("test_data.csv", na_values=[" ", "?", "#"])
assembly_line_data = pd.read_csv("assembly_line_info.csv", na_values=[" ", "?", "#"])
car_variant_data = pd.read_csv("car_variant_data.csv", na_values=[" ", "?", "#"])
issue_info_data = pd.read_csv("issue_info.csv", na_values=[" ", "?", "#"])
log_report_type_data = pd.read_csv("log_report_type_data.csv", na_values=[" ", "?", "#"])

# %%
print("The shape of train data is: ",train_data.shape)
print("The shape of test data is: ",test_data.shape)
print("The shape of assembly line data is: ",assembly_line_data.shape)
print("The shape of car variant data is: ",car_variant_data.shape)
print("The shape of issue info data is: ",issue_info_data.shape)
print("The shape of the log report data is: ",log_report_type_data.shape)
# Out:
# The shape of train data is:  (5904, 3)
# The shape of test data is:  (1477, 2)
# The shape of assembly line data is:  (21076, 2)
# The shape of car variant data is:  (31170, 2)
# The shape of issue info data is:  (18552, 2)
# The shape of the log report data is:  (58671, 3)

# %%
train_data.head()
# Out:
#       id      factory_number  downtime_duration
# 0  13366  factory_number_415                  1
# 1   6783  factory_number_474                  0
# 2   9519  factory_number_931                  1
# 3  10202  factory_number_700                  1
# 4   4555  factory_number_600                  2

# %%
train_data.downtime_duration.value_counts()
# Out:
# 0    3827
# 1    1496
# 2     581
# Name: downtime_duration, dtype: int64

# %%
test_data.head()
# Out:
#       id      factory_number
# 0   3340  factory_number_344
# 1  14067  factory_number_933
# 2   1134   factory_number_16
# 3     27  factory_number_793
# 4   9793  factory_number_344

# %%
print(assembly_line_data.shape) 
print(assembly_line_data.id.nunique())
assembly_line_data.head()
# Out:
# (21076, 2)
# 18552
#      id    assembly_line_type
# 0  6597  assembly_line_type_8
# 1  8011  assembly_line_type_8
# 2  2597  assembly_line_type_8
# 3  5022  assembly_line_type_8
# 4  6852  assembly_line_type_8

# %%
print(issue_info_data.shape)
print(issue_info_data.id.nunique())
print(issue_info_data.issue_type.nunique())
issue_info_data.head()
# Out:
# (18552, 2)
# 18552
# 5
#        id  issue_type
# 10448   1           1
# 8351    2           2
# 10957   3           1
# 11106   4           4
# 7736    5           2

# %%
print(car_variant_data.shape)
print(car_variant_data.id.nunique())
print(car_variant_data.car_variant.nunique())
car_variant_data.head()
# Out:
# (31170, 2)
# 18552
# 53
#        id  car_variant
# 18299   1           11
# 18300   1           13
# 14536   2           34
# 14535   2           35
# 19226   3           11

# %%
print(log_report_type_data.shape)
print(log_report_type_data.id.nunique())
print(log_report_type_data.log_report_type.nunique()) 
log_report_type_data.head()
# Out:
# (58671, 2)
# 18552
# 386
#        id  log_report_type
# 36197   1               68
# 36199   1              179
# 36198   1              345
# 27670   2              233
# 27669   2              235

# %%
# renaming thr column values, sorting and changing the type to int
assembly_line_data.assembly_line_type = assembly_line_data["assembly_line_type"].str.replace("assembly_line_type_","")
assembly_line_data.assembly_line_type = assembly_line_data.assembly_line_type.astype("int")
assembly_line_data = assembly_line_data.sort_values(by=["id","assembly_line_type"])
assembly_line_data.head()
# Out:
#        id  assembly_line_type
# 11285   1                   6
# 11284   1                   8
# 9069    2                   2
# 11953   3                   8
# 12102   4                   2

# %%
# This function merges rows into one cell based on id
def merge_rows(data,id_col,merge_col):
    unique_id = data[id_col].unique() # get unique names
    new_data = []                 # data list for output dataframe
    for u in unique_id:          # for each unique name
        subdf = data[data[id_col] == u] # get rows with this unique name
        s = ""
        for i in subdf[merge_col]:
            s += ""+str(i)+","      # join all info cells for that name
        new_data.append([u, s[:-1]])

    newdf = pd.DataFrame(data=new_data, columns=[id_col,merge_col])
    return newdf

# %%
# Merging the assembly data based on id
assembly_line_data_merged =merge_rows(assembly_line_data,id_col="id",merge_col="assembly_line_type")

# %%
assembly_line_data_merged.head()
# Out:
#    id assembly_line_type
# 0   1                6,8
# 1   2                  2
# 2   3                  8
# 3   4                  2
# 4   5                  2

# %%
# renaming thr column values, sorting and changing the type to int
car_variant_data.car_variant = car_variant_data["car_variant"].str.replace("car_variant_","")
car_variant_data.car_variant = car_variant_data.car_variant.astype("int")
car_variant_data = car_variant_data.sort_values(by=["id","car_variant"])
car_variant_data.head()
# Out:
#        id  car_variant
# 18299   1           11
# 18300   1           13
# 14536   2           34
# 14535   2           35
# 19226   3           11

# %%
# Merging the car_variant data based on id
car_variant_data_merged = merge_rows(car_variant_data, id_col="id", merge_col="car_variant")

# %%
car_variant_data_merged.head()
# Out:
#    id car_variant
# 0   1       11,13
# 1   2       34,35
# 2   3          11
# 3   4          47
# 4   5       34,35

# %%
# renaming thr column values, sorting, changing the type to int and aggregating the volume column
log_report_type_data.log_report_type = log_report_type_data["log_report_type"].str.replace("log_report_type_","")
log_report_type_data.log_report_type = log_report_type_data.log_report_type.astype("int")
log_report_type_data = log_report_type_data.sort_values(by=["id","log_report_type"])
log_report_type_data_aggregated = log_report_type_data.groupby("id",as_index=False).agg({"volume":"sum"})
log_report_type_data.head()
# Out:
#        id  log_report_type  volume
# 36197   1               68       2
# 36199   1              179       1
# 36198   1              345       2
# 27670   2              233       1
# 27669   2              235       1

# %%
# Dropping the Volume Column
log_report_type_data.drop("volume", axis =1,inplace=True)

# %%
# merging the log_report_type based on id
log_report_type_data_merged = merge_rows(log_report_type_data,id_col="id", merge_col="log_report_type")

# %%
log_report_type_data_merged.head()
# Out:
#    id      log_report_type
# 0   1           68,179,345
# 1   2  233,235,312,313,315
# 2   3                  171
# 3   4                  370
# 4   5              232,312

# %%
#Combining the merged log_report_type and aggregated Volume data
log_report_type_data_aggregated_merged = pd.merge(log_report_type_data_merged,
                                                  log_report_type_data_aggregated, on="id",
                                                 how="left")

# %%
log_report_type_data_aggregated_merged.head()
# Out:
#    id      log_report_type  volume
# 0   1           68,179,345       5
# 1   2  233,235,312,313,315       5
# 2   3                  171       2
# 3   4                  370       3
# 4   5              232,312      17

# %%
# renaming thr column values, sorting and changing the type to int
issue_info_data.issue_type = issue_info_data["issue_type"].str.replace("issue_type_","")
issue_info_data.issue_type = issue_info_data.issue_type.astype("int")
issue_info_data = issue_info_data.sort_values(by=["id","issue_type"])
issue_info_data.head()
# Out:
#        id  issue_type
# 10448   1           1
# 8351    2           2
# 10957   3           1
# 11106   4           4
# 7736    5           2

# %% [markdown]
# # Merging The Data

# %%
# Merging issue_info and assembly_line_merged_data based on id
df_issue_assembly = pd.merge(issue_info_data, assembly_line_data_merged, on="id", how="inner")
print(df_issue_assembly.shape)
print(df_issue_assembly.id.nunique())
df_issue_assembly.head()
# Out:
# (18552, 3)
# 18552
#    id  issue_type assembly_line_type
# 0   1           1                6,8
# 1   2           2                  2
# 2   3           1                  8
# 3   4           4                  2
# 4   5           2                  2

# %%
# merging the issue_assembly_data with car_variant_merged_data based on id
df_issue_assembly_car = pd.merge(df_issue_assembly, car_variant_data_merged, on="id",how="inner")
print(df_issue_assembly_car.shape)
print(df_issue_assembly_car.id.nunique())
df_issue_assembly_car.head()
# Out:
# (18552, 4)
# 18552
#    id  issue_type assembly_line_type car_variant
# 0   1           1                6,8       11,13
# 1   2           2                  2       34,35
# 2   3           1                  8          11
# 3   4           4                  2          47
# 4   5           2                  2       34,35

# %%
# Merging issue_assembly_car data with log_report_type_data_aggregated_merged data
df_issue_assembly_car_log = pd.merge(df_issue_assembly_car, log_report_type_data_aggregated_merged, 
                                     on="id",
                                     how="inner")
print(df_issue_assembly_car_log.shape)
print(df_issue_assembly_car_log.id.nunique())
df_issue_assembly_car_log.head()
# Out:
# (18552, 6)
# 18552
#    id  issue_type assembly_line_type car_variant      log_report_type  volume
# 0   1           1                6,8       11,13           68,179,345       5
# 1   2           2                  2       34,35  233,235,312,313,315       5
# 2   3           1                  8          11                  171       2
# 3   4           4                  2          47                  370       3
# 4   5           2                  2       34,35              232,312      17

# %%
# Performing Label Encoding
encode_columns = ["assembly_line_type","car_variant","log_report_type"]
for i in range(0,len(df_issue_assembly_car_log.columns)):
    j=df_issue_assembly_car_log.columns[i]
    if(j in encode_columns):
        label_encoder = LabelEncoder()                  # converts the character array to numeric array. Assigns levels to unique labels.
        label_encoder.fit(df_issue_assembly_car_log[j])
        df_issue_assembly_car_log[j]  = label_encoder.transform(df_issue_assembly_car_log[j])
        df_issue_assembly_car_log[j]  = df_issue_assembly_car_log[j].astype('category')

# %%
# Creating the Train Data_set
df_train = pd.merge(train_data, df_issue_assembly_car_log, on="id",how="inner")
print(df_train.shape)
df_train.head()
# Out:
# (5904, 8)
#       id      factory_number  downtime_duration  issue_type  \
# 0  13366  factory_number_415                  1           4
# 1   6783  factory_number_474                  0           2
# 2   9519  factory_number_931                  1           2
# 3  10202  factory_number_700                  1           1
# 4   4555  factory_number_600                  2           2
#
#   assembly_line_type car_variant log_report_type  volume
# 0                  8         245            1073       1
# 1                  8         244             801       9
# 2                 51         161            2151      11
# 3                 51          32            1393       1
# 4                 51         161            2175      44

# %%
# Creating the Test Data set
df_test = pd.merge(test_data, df_issue_assembly_car_log,on="id",how="inner")
print(df_test.shape) 
df_test.head()
# Out:
# (1477, 7)
#       id      factory_number  issue_type assembly_line_type car_variant  \
# 0   3340  factory_number_344           4                  8         245
# 1  14067  factory_number_933           1                  8         180
# 2   1134   factory_number_16           1                 51          32
# 3     27  factory_number_793           1                 51          32
# 4   9793  factory_number_344           2                  8         244
#
#   log_report_type  volume
# 0            1073       2
# 1              71       1
# 2             254      16
# 3            2035       5
# 4             849      24

# %%
# Printing the nunique values
print(df_train.log_report_type.nunique())
print(df_train.assembly_line_type.nunique())
print(df_train.car_variant.nunique())
# Out:
# 1108
# 43
# 197

# %%
# Printing the nunique values
print(df_test.log_report_type.nunique())
print(df_test.assembly_line_type.nunique())
print(df_test.car_variant.nunique())
# Out:
# 447
# 33
# 103

# %%
# Type casting the column back to int type
for col in encode_columns:
    df_train[col]= df_train[col].astype("int")
    df_test[col] = df_test[col].astype("int")

# %%
df_train.dtypes
# Out:
# id                     int64
# factory_number        object
# downtime_duration      int64
# issue_type             int64
# assembly_line_type     int64
# car_variant            int64
# log_report_type        int64
# volume                 int64
# dtype: object

# %%
df_test.dtypes
# Out:
# id                     int64
# factory_number        object
# issue_type             int64
# assembly_line_type     int64
# car_variant            int64
# log_report_type        int64
# volume                 int64
# dtype: object

# %%
# renaming thr column values, sorting and changing the type to int both on train and test data
df_train.factory_number = df_train["factory_number"].str.replace("factory_number_","")
df_train.factory_number = df_train.factory_number.astype("int")
df_test.factory_number = df_test["factory_number"].str.replace("factory_number_","")
df_test.factory_number = df_test.factory_number.astype("int")

# %%
# chamging the data type of target variable to category
df_train.downtime_duration = df_train.downtime_duration.astype("category")

# %%
df_train.dtypes
# Out:
# id                       int64
# factory_number           int64
# downtime_duration     category
# issue_type               int64
# assembly_line_type       int64
# car_variant              int64
# log_report_type          int64
# volume                   int64
# dtype: object

# %%
df_test.dtypes
# Out:
# id                    int64
# factory_number        int64
# issue_type            int64
# assembly_line_type    int64
# car_variant           int64
# log_report_type       int64
# volume                int64
# dtype: object

# %%
# Creating x_train
x_train = df_train.drop("downtime_duration",axis=1)

# %%
# Creating y_train
y_train = df_train.downtime_duration

# %%
# Building Decison Tree Classifier with CV
paramgrid = {"criterion": ["gini", "entropy"], 
               "max_depth": list(range(2,4,1)), 
              "min_samples_leaf": list(range(5,7,1)),
             "min_samples_split": [1,2,5,10]}
dt_gridsearch = GridSearchCV(DecisionTreeClassifier(class_weight="balanced", random_state=1234),
                             param_grid=paramgrid,n_jobs=-1,cv=10)
dt_gridsearch.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=10, error_score=nan,
#              estimator=DecisionTreeClassifier(ccp_alpha=0.0,
#                                               class_weight='balanced',
#                                               criterion='gini', max_depth=None,
#                                               max_features=None,
#                                               max_leaf_nodes=None,
#                                               min_impurity_decrease=0.0,
#                                               min_impurity_split=None,
#                                               min_samples_leaf=1,
#                                               min_samples_split=2,
#                                               min_weight_fraction_leaf=0.0,
#                                               presort='deprecated',
#                                               random_state=1234,
#                                               splitter='best'),
#              iid='deprecated', n_jobs=-1,
#              param_grid={'criterion': ['gini', 'entropy'], 'max_depth': [2, 3],
#                          'min_samples_leaf': [5, 6],
#                          'min_samples_split': [1, 2, 5, 10]},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=None, verbose=0)

# %%
y_train_predict_dt_cv = dt_gridsearch.best_estimator_.predict(x_train)
y_test_predict_dt_cv = dt_gridsearch.best_estimator_.predict(df_test)

# %%
def classifcation_report_train_test(y_train, y_train_pred):

    print('''
            =========================================
               CLASSIFICATION REPORT FOR TRAIN DATA
            =========================================
            ''')
    print(classification_report(y_train, y_train_pred))

# %%
classifcation_report_train_test(y_train,y_train_predict_dt_cv)
# Out:
#             =========================================
#                CLASSIFICATION REPORT FOR TRAIN DATA
#             =========================================
#
#               precision    recall  f1-score   support
#
#            0       0.84      0.53      0.65      3827
#            1       0.37      0.51      0.43      1496
#            2       0.34      0.85      0.49       581
#
#     accuracy                           0.56      5904
#    macro avg       0.52      0.63      0.52      5904
# weighted avg       0.67      0.56      0.58      5904

# %%
df_test_dt_cv = df_test.copy()
df_test_dt_cv["downtime_duration"] = y_test_predict_dt_cv
df_test_dt_cv.head()
# Out:
#       id  factory_number  issue_type  assembly_line_type  car_variant  \
# 0   3340             344           4                   8          245
# 1  14067             933           1                   8          180
# 2   1134              16           1                  51           32
# 3     27             793           1                  51           32
# 4   9793             344           2                   8          244
#
#    log_report_type  volume  downtime_duration
# 0             1073       2                  0
# 1               71       1                  0
# 2              254      16                  1
# 3             2035       5                  1
# 4              849      24                  0

# %%
df_test_dt_cv.drop(["factory_number", "issue_type", "assembly_line_type", "car_variant",
                   "log_report_type", "volume"], axis=1, inplace = True)

# %%
df_test_dt_cv.head()
# Out:
#       id  downtime_duration
# 0   3340                  0
# 1  14067                  0
# 2   1134                  1
# 3     27                  1
# 4   9793                  0

# %%
# Creating the csv file
df_test_dt_cv.to_csv("df_test_dt_cv.csv", sep=',',index=False)

# %%
# Building a Random Forest
param_grid = {"n_estimators" : [25,50,75],
           "max_depth" : [2,3,4,5],
           "min_samples_leaf" : [2,3,4,5],'max_features':[3,5,7],
           "class_weight" : ['balanced','balanced_subsample']}
rf_grid = GridSearchCV(RandomForestClassifier(n_jobs=-1,random_state=1),param_grid=param_grid,
                      cv= 10)
rf_grid.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=10, error_score=nan,
#              estimator=RandomForestClassifier(bootstrap=True, ccp_alpha=0.0,
#                                               class_weight=None,
#                                               criterion='gini', max_depth=None,
#                                               max_features='auto',
#                                               max_leaf_nodes=None,
#                                               max_samples=None,
#                                               min_impurity_decrease=0.0,
#                                               min_impurity_split=None,
#                                               min_samples_leaf=1,
#                                               min_samples_split=2,
#                                               min_weight_fraction_leaf=0.0,
#                                               n_estimators=100, n_jobs=-1,
#                                               oob_score=False, random_state=1,
#                                               verbose=0, warm_start=False),
#              iid='deprecated', n_jobs=None,
#              param_grid={'class_weight': ['balanced', 'balanced_subsample'],
#                          'max_depth': [2, 3, 4, 5], 'max_features': [3, 5, 7],
#                          'min_samples_leaf': [2, 3, 4, 5],
#                          'n_estimators': [25, 50, 75]},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=None, verbose=0)

# %%
y_train_predict_rf_cv = rf_grid.best_estimator_.predict(x_train)
y_test_predict_rf_cv = rf_grid.best_estimator_.predict(df_test)

# %%
classifcation_report_train_test(y_train, y_train_predict_rf_cv)
# Out:
#             =========================================
#                CLASSIFICATION REPORT FOR TRAIN DATA
#             =========================================
#
#               precision    recall  f1-score   support
#
#            0       0.91      0.65      0.76      3827
#            1       0.50      0.61      0.55      1496
#            2       0.38      0.87      0.53       581
#
#     accuracy                           0.66      5904
#    macro avg       0.60      0.71      0.61      5904
# weighted avg       0.75      0.66      0.68      5904

# %%
df_test_rf_cv = df_test.copy()
df_test_rf_cv["downtime_duration"] = y_test_predict_rf_cv

# %%
df_test_rf_cv.drop(["factory_number", "issue_type", "assembly_line_type", "car_variant",
                   "log_report_type", "volume"], axis=1, inplace = True)
df_test_rf_cv.head()
# Out:
#       id  downtime_duration
# 0   3340                  0
# 1  14067                  0
# 2   1134                  2
# 3     27                  0
# 4   9793                  0

# %%
# Creating the csv file
df_test_rf_cv.to_csv("df_test_rf_cv.csv",sep=",", index=False)

# %%
# Bulinding LightGBM classifier with CV
lgbm = LGBMClassifier(random_state=1234)
gridParams = {
    'learning_rate': [0.005, 0.01,0.1,0.3],# shrinkage rate at which model learns
    'n_estimators': [50,100,150],# Number of gradient boosted trees. Equivalent to number of boosting rounds.
    'num_leaves': [6,8,12,16], # large num_leaves helps improve accuracy but might lead to over-fitting
    'boosting_type' : ['gbdt', 'dart'], # for better accuracy 
    'max_bin':[255, 510], # large max_bin helps improve accuracy but might slow down training progress
    'random_state' : [500],# Random number seed.
    'colsample_bytree' : [0.64, 0.65, 0.66],# Subsample ratio of columns when constructing each tree.
    'subsample' : [0.7,0.75,0.8],# Subsample ratio of the training instance.
    'reg_alpha' : [1,1.2],# L1 regularization term on weights
    'reg_lambda' : [1,1.2,1.4],# L2 regularization term on weights
    }
grid_lgbm = GridSearchCV(lgbm, gridParams, verbose=10, cv=5, n_jobs=-1)
grid_lgbm.fit(x_train, y_train)
# Out:
# Fitting 5 folds for each of 10368 candidates, totalling 51840 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   5 tasks      | elapsed:    5.3s
# [Parallel(n_jobs=-1)]: Done  10 tasks      | elapsed:    5.5s
# [Parallel(n_jobs=-1)]: Done  17 tasks      | elapsed:    6.0s
# [Parallel(n_jobs=-1)]: Done  24 tasks      | elapsed:    6.3s
# [Parallel(n_jobs=-1)]: Done  33 tasks      | elapsed:    7.0s
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:    7.5s
# [Parallel(n_jobs=-1)]: Done  53 tasks      | elapsed:    8.2s
# [Parallel(n_jobs=-1)]: Done  64 tasks      | elapsed:    8.8s
# [Parallel(n_jobs=-1)]: Done  77 tasks      | elapsed:   10.1s
# [Parallel(n_jobs=-1)]: Done  90 tasks      | elapsed:   11.0s
# [Parallel(n_jobs=-1)]: Done 105 tasks      | elapsed:   12.1s
# [Parallel(n_jobs=-1)]: Done 120 tasks      | elapsed:   13.0s
# [Parallel(n_jobs=-1)]: Done 137 tasks      | elapsed:   14.3s
# [Parallel(n_jobs=-1)]: Done 154 tasks      | elapsed:   15.5s
# [Parallel(n_jobs=-1)]: Done 173 tasks      | elapsed:   16.8s
# [Parallel(n_jobs=-1)]: Done 192 tasks      | elapsed:   18.3s
# [Parallel(n_jobs=-1)]: Done 213 tasks      | elapsed:   20.0s
# [Parallel(n_jobs=-1)]: Done 234 tasks      | elapsed:   21.7s
# [Parallel(n_jobs=-1)]: Done 257 tasks      | elapsed:   23.6s
# [Parallel(n_jobs=-1)]: Done 280 tasks      | elapsed:   25.7s
# [Parallel(n_jobs=-1)]: Done 305 tasks      | elapsed:   27.9s
# [Parallel(n_jobs=-1)]: Done 330 tasks      | elapsed:   30.3s
# [Parallel(n_jobs=-1)]: Done 357 tasks      | elapsed:   32.8s
# [Parallel(n_jobs=-1)]: Done 384 tasks      | elapsed:   35.8s
# [Parallel(n_jobs=-1)]: Done 413 tasks      | elapsed:   39.0s
# [Parallel(n_jobs=-1)]: Done 442 tasks      | elapsed:   42.1s
# [Parallel(n_jobs=-1)]: Done 473 tasks      | elapsed:   45.9s
# [Parallel(n_jobs=-1)]: Done 504 tasks      | elapsed:   49.6s
# [Parallel(n_jobs=-1)]: Done 537 tasks      | elapsed:   53.6s
# [Parallel(n_jobs=-1)]: Done 570 tasks      | elapsed:   58.5s
# [Parallel(n_jobs=-1)]: Done 605 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done 640 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done 677 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 714 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=-1)]: Done 753 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=-1)]: Done 792 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=-1)]: Done 833 tasks      | elapsed:  1.7min
# [Parallel(n_jobs=-1)]: Done 874 tasks      | elapsed:  1.8min
# [Parallel(n_jobs=-1)]: Done 917 tasks      | elapsed:  1.9min
# [Parallel(n_jobs=-1)]: Done 960 tasks      | elapsed:  2.1min
# [Parallel(n_jobs=-1)]: Done 1005 tasks      | elapsed:  2.3min
# [Parallel(n_jobs=-1)]: Done 1050 tasks      | elapsed:  2.5min
# [Parallel(n_jobs=-1)]: Done 1097 tasks      | elapsed:  2.6min
# [Parallel(n_jobs=-1)]: Done 1144 tasks      | elapsed:  2.7min
# [Parallel(n_jobs=-1)]: Done 1193 tasks      | elapsed:  2.8min
# [Parallel(n_jobs=-1)]: Done 1242 tasks      | elapsed:  2.9min
# [Parallel(n_jobs=-1)]: Done 1293 tasks      | elapsed:  3.0min
# [Parallel(n_jobs=-1)]: Done 1344 tasks      | elapsed:  3.1min
# [Parallel(n_jobs=-1)]: Done 1397 tasks      | elapsed:  3.2min
# [Parallel(n_jobs=-1)]: Done 1450 tasks      | elapsed:  3.3min
# [Parallel(n_jobs=-1)]: Done 1505 tasks      | elapsed:  3.4min
# [Parallel(n_jobs=-1)]: Done 1560 tasks      | elapsed:  3.5min
# [Parallel(n_jobs=-1)]: Done 1617 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=-1)]: Done 1674 tasks      | elapsed:  3.8min
# [Parallel(n_jobs=-1)]: Done 1733 tasks      | elapsed:  4.1min
# [Parallel(n_jobs=-1)]: Done 1792 tasks      | elapsed:  4.3min
# [Parallel(n_jobs=-1)]: Done 1853 tasks      | elapsed:  4.4min
# [Parallel(n_jobs=-1)]: Done 1914 tasks      | elapsed:  4.6min
# [Parallel(n_jobs=-1)]: Done 1977 tasks      | elapsed:  4.8min
# [Parallel(n_jobs=-1)]: Done 2040 tasks      | elapsed:  5.1min
# [Parallel(n_jobs=-1)]: Done 2105 tasks      | elapsed:  5.5min
# [Parallel(n_jobs=-1)]: Done 2170 tasks      | elapsed:  5.7min
# [Parallel(n_jobs=-1)]: Done 2237 tasks      | elapsed:  5.8min
# [Parallel(n_jobs=-1)]: Done 2304 tasks      | elapsed:  5.9min
# [Parallel(n_jobs=-1)]: Done 2373 tasks      | elapsed:  6.0min
# [Parallel(n_jobs=-1)]: Done 2442 tasks      | elapsed:  6.1min
# [Parallel(n_jobs=-1)]: Done 2513 tasks      | elapsed:  6.2min
# [Parallel(n_jobs=-1)]: Done 2584 tasks      | elapsed:  6.3min
# [Parallel(n_jobs=-1)]: Done 2657 tasks      | elapsed:  6.4min
# [Parallel(n_jobs=-1)]: Done 2730 tasks      | elapsed:  6.6min
# [Parallel(n_jobs=-1)]: Done 2805 tasks      | elapsed:  6.7min
# [Parallel(n_jobs=-1)]: Done 2880 tasks      | elapsed:  6.9min
# [Parallel(n_jobs=-1)]: Done 2957 tasks      | elapsed:  7.1min
# [Parallel(n_jobs=-1)]: Done 3034 tasks      | elapsed:  7.3min
# [Parallel(n_jobs=-1)]: Done 3113 tasks      | elapsed:  7.6min
# [Parallel(n_jobs=-1)]: Done 3192 tasks      | elapsed:  7.9min
# [Parallel(n_jobs=-1)]: Done 3273 tasks      | elapsed:  8.0min
# [Parallel(n_jobs=-1)]: Done 3354 tasks      | elapsed:  8.1min
# [Parallel(n_jobs=-1)]: Done 3437 tasks      | elapsed:  8.2min
# [Parallel(n_jobs=-1)]: Done 3520 tasks      | elapsed:  8.4min
# [Parallel(n_jobs=-1)]: Done 3605 tasks      | elapsed:  8.5min
# [Parallel(n_jobs=-1)]: Done 3690 tasks      | elapsed:  8.7min
# [Parallel(n_jobs=-1)]: Done 3777 tasks      | elapsed:  8.8min
# [Parallel(n_jobs=-1)]: Done 3864 tasks      | elapsed:  9.1min
# [Parallel(n_jobs=-1)]: Done 3953 tasks      | elapsed:  9.3min
# [Parallel(n_jobs=-1)]: Done 4042 tasks      | elapsed:  9.5min
# [Parallel(n_jobs=-1)]: Done 4133 tasks      | elapsed:  9.9min
# [Parallel(n_jobs=-1)]: Done 4224 tasks      | elapsed: 10.3min
# [Parallel(n_jobs=-1)]: Done 4317 tasks      | elapsed: 10.9min
# [Parallel(n_jobs=-1)]: Done 4410 tasks      | elapsed: 11.1min
# [Parallel(n_jobs=-1)]: Done 4505 tasks      | elapsed: 11.2min
# [Parallel(n_jobs=-1)]: Done 4600 tasks      | elapsed: 11.4min
# [Parallel(n_jobs=-1)]: Done 4697 tasks      | elapsed: 11.5min
# [Parallel(n_jobs=-1)]: Done 4794 tasks      | elapsed: 11.7min
# [Parallel(n_jobs=-1)]: Done 4893 tasks      | elapsed: 12.0min
# [Parallel(n_jobs=-1)]: Done 4992 tasks      | elapsed: 12.2min
# [Parallel(n_jobs=-1)]: Done 5093 tasks      | elapsed: 12.5min
# [Parallel(n_jobs=-1)]: Done 5194 tasks      | elapsed: 12.7min
# [Parallel(n_jobs=-1)]: Done 5297 tasks      | elapsed: 13.0min
# [Parallel(n_jobs=-1)]: Done 5400 tasks      | elapsed: 13.4min
# [Parallel(n_jobs=-1)]: Done 5505 tasks      | elapsed: 13.6min
# [Parallel(n_jobs=-1)]: Done 5610 tasks      | elapsed: 13.8min
# [Parallel(n_jobs=-1)]: Done 5717 tasks      | elapsed: 14.0min
# [Parallel(n_jobs=-1)]: Done 5824 tasks      | elapsed: 14.2min
# [Parallel(n_jobs=-1)]: Done 5933 tasks      | elapsed: 14.4min
# [Parallel(n_jobs=-1)]: Done 6042 tasks      | elapsed: 14.7min
# [Parallel(n_jobs=-1)]: Done 6153 tasks      | elapsed: 15.1min
# [Parallel(n_jobs=-1)]: Done 6264 tasks      | elapsed: 15.5min
# [Parallel(n_jobs=-1)]: Done 6377 tasks      | elapsed: 16.1min
# [Parallel(n_jobs=-1)]: Done 6490 tasks      | elapsed: 16.6min
# [Parallel(n_jobs=-1)]: Done 6605 tasks      | elapsed: 16.7min
# [Parallel(n_jobs=-1)]: Done 6720 tasks      | elapsed: 16.9min
# [Parallel(n_jobs=-1)]: Done 6837 tasks      | elapsed: 17.0min
# [Parallel(n_jobs=-1)]: Done 6954 tasks      | elapsed: 17.2min
# [Parallel(n_jobs=-1)]: Done 7073 tasks      | elapsed: 17.4min
# [Parallel(n_jobs=-1)]: Done 7192 tasks      | elapsed: 17.7min
# [Parallel(n_jobs=-1)]: Done 7313 tasks      | elapsed: 18.0min
# [Parallel(n_jobs=-1)]: Done 7434 tasks      | elapsed: 18.3min
# [Parallel(n_jobs=-1)]: Done 7557 tasks      | elapsed: 18.6min
# [Parallel(n_jobs=-1)]: Done 7680 tasks      | elapsed: 18.8min
# [Parallel(n_jobs=-1)]: Done 7805 tasks      | elapsed: 18.9min
# [Parallel(n_jobs=-1)]: Done 7930 tasks      | elapsed: 19.1min
# [Parallel(n_jobs=-1)]: Done 8057 tasks      | elapsed: 19.3min
# [Parallel(n_jobs=-1)]: Done 8184 tasks      | elapsed: 19.6min
# [Parallel(n_jobs=-1)]: Done 8313 tasks      | elapsed: 19.9min
# [Parallel(n_jobs=-1)]: Done 8442 tasks      | elapsed: 20.2min
# [Parallel(n_jobs=-1)]: Done 8573 tasks      | elapsed: 20.7min
# [Parallel(n_jobs=-1)]: Done 8704 tasks      | elapsed: 21.1min
# [Parallel(n_jobs=-1)]: Done 8837 tasks      | elapsed: 21.4min
# [Parallel(n_jobs=-1)]: Done 8970 tasks      | elapsed: 21.5min
# [Parallel(n_jobs=-1)]: Done 9105 tasks      | elapsed: 21.7min
# [Parallel(n_jobs=-1)]: Done 9240 tasks      | elapsed: 21.9min
# [Parallel(n_jobs=-1)]: Done 9377 tasks      | elapsed: 22.2min
# [Parallel(n_jobs=-1)]: Done 9514 tasks      | elapsed: 22.4min
# [Parallel(n_jobs=-1)]: Done 9653 tasks      | elapsed: 22.8min
# [Parallel(n_jobs=-1)]: Done 9792 tasks      | elapsed: 23.0min
# [Parallel(n_jobs=-1)]: Done 9933 tasks      | elapsed: 23.1min
# [Parallel(n_jobs=-1)]: Done 10074 tasks      | elapsed: 23.3min
# [Parallel(n_jobs=-1)]: Done 10217 tasks      | elapsed: 23.5min
# [Parallel(n_jobs=-1)]: Done 10360 tasks      | elapsed: 23.8min
# [Parallel(n_jobs=-1)]: Done 10505 tasks      | elapsed: 24.1min
# [Parallel(n_jobs=-1)]: Done 10650 tasks      | elapsed: 24.5min
# [Parallel(n_jobs=-1)]: Done 10797 tasks      | elapsed: 24.9min
# [Parallel(n_jobs=-1)]: Done 10944 tasks      | elapsed: 25.0min
# [Parallel(n_jobs=-1)]: Done 46200 tasks      | elapsed: 163.6min
# [Parallel(n_jobs=-1)]: Done 46505 tasks      | elapsed: 165.6min
# [Parallel(n_jobs=-1)]: Done 46810 tasks      | elapsed: 166.1min
# [Parallel(n_jobs=-1)]: Done 47117 tasks      | elapsed: 167.3min
# [Parallel(n_jobs=-1)]: Done 47424 tasks      | elapsed: 169.3min
# [Parallel(n_jobs=-1)]: Done 47733 tasks      | elapsed: 170.3min
# [Parallel(n_jobs=-1)]: Done 48042 tasks      | elapsed: 171.0min
# [Parallel(n_jobs=-1)]: Done 48353 tasks      | elapsed: 172.9min
# [Parallel(n_jobs=-1)]: Done 48664 tasks      | elapsed: 175.7min
# [Parallel(n_jobs=-1)]: Done 48977 tasks      | elapsed: 176.5min
# [Parallel(n_jobs=-1)]: Done 49290 tasks      | elapsed: 178.1min
# [Parallel(n_jobs=-1)]: Done 49605 tasks      | elapsed: 181.0min
# [Parallel(n_jobs=-1)]: Done 49920 tasks      | elapsed: 182.4min
# [Parallel(n_jobs=-1)]: Done 50237 tasks      | elapsed: 183.5min
# [Parallel(n_jobs=-1)]: Done 50554 tasks      | elapsed: 185.5min
# [Parallel(n_jobs=-1)]: Done 50873 tasks      | elapsed: 188.0min
# [Parallel(n_jobs=-1)]: Done 51192 tasks      | elapsed: 188.8min
# [Parallel(n_jobs=-1)]: Done 51513 tasks      | elapsed: 190.7min
# [Parallel(n_jobs=-1)]: Done 51840 out of 51840 | elapsed: 194.1min finished
# GridSearchCV(cv=5, error_score=nan,
#              estimator=LGBMClassifier(boosting_type='gbdt', class_weight=None,
#                                       colsample_bytree=1.0,
#                                       importance_type='split',
#                                       learning_rate=0.1, max_depth=-1,
#                                       min_child_samples=20,
#                                       min_child_weight=0.001,
#                                       min_split_gain=0.0, n_estimators=100,
#                                       n_jobs=-1, num_leaves=31, objective=None,
#                                       random_state=1234, reg_alpha=0.0,
#                                       reg_lambda=0.0, silent=Tru...
#              param_grid={'boosting_type': ['gbdt', 'dart'],
#                          'colsample_bytree': [0.64, 0.65, 0.66],
#                          'learning_rate': [0.005, 0.01, 0.1, 0.3],
#                          'max_bin': [255, 510], 'n_estimators': [50, 100, 150],
#                          'num_leaves': [6, 8, 12, 16], 'objective': ['binary'],
#                          'random_state': [500], 'reg_alpha': [1, 1.2],
#                          'reg_lambda': [1, 1.2, 1.4],
#                          'subsample': [0.7, 0.75, 0.8]},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=None, verbose=10)

# %%
y_train_predict_lgbm_cv = grid_lgbm.best_estimator_.predict(x_train)
y_test_predict_lgbm_cv = grid_lgbm.best_estimator_.predict(df_test)

# %%
classifcation_report_train_test(y_train, y_train_predict_lgbm_cv)
# Out:
#             =========================================
#                CLASSIFICATION REPORT FOR TRAIN DATA
#             =========================================
#
#               precision    recall  f1-score   support
#
#            0       0.86      0.92      0.89      3827
#            1       0.75      0.63      0.68      1496
#            2       0.73      0.74      0.73       581
#
#     accuracy                           0.83      5904
#    macro avg       0.78      0.76      0.77      5904
# weighted avg       0.82      0.83      0.82      5904

# %%
df_test_lgbm_cv = df_test.copy() 
df_test_lgbm_cv["downtime_duration"] = y_test_predict_lgbm_cv

# %%
df_test_lgbm_cv.drop(["factory_number", "issue_type", "assembly_line_type", "car_variant",
                   "log_report_type", "volume"], axis=1, inplace = True)

# %%
df_test_lgbm_cv.head()
# Out:
#       id  downtime_duration
# 0   3340                  0
# 1  14067                  0
# 2   1134                  2
# 3     27                  0
# 4   9793                  0

# %%
# Creating the csv file
df_test_lgbm_cv.to_csv("df_test_lgbm_cv.csv", sep=",", index=False)

# %%
# Building Xgboost Classifier

params = {
        'min_child_weight': [1, 5, 10],
        'gamma': [0.5, 1, 1.5, 2, 5],
        'subsample': [0.6, 0.8, 1.0],
        'colsample_bytree': [0.6, 0.8, 1.0],
        'max_depth': [3, 4, 5]
        }
model = XGBClassifier(n_estimators=200,learning_rate=0.02, random_state=1234)

# %%
gd_xgb = GridSearchCV(model, param_grid=params,n_jobs=-1,verbose=10,cv=10)
gd_xgb.fit(x_train, y_train)
# Out:
# Fitting 10 folds for each of 405 candidates, totalling 4050 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   5 tasks      | elapsed:    4.4s
# [Parallel(n_jobs=-1)]: Done  10 tasks      | elapsed:    6.7s
# [Parallel(n_jobs=-1)]: Done  17 tasks      | elapsed:   11.0s
# [Parallel(n_jobs=-1)]: Done  24 tasks      | elapsed:   13.3s
# [Parallel(n_jobs=-1)]: Done  33 tasks      | elapsed:   19.6s
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:   24.0s
# [Parallel(n_jobs=-1)]: Done  53 tasks      | elapsed:   30.5s
# [Parallel(n_jobs=-1)]: Done  64 tasks      | elapsed:   35.5s
# [Parallel(n_jobs=-1)]: Done  77 tasks      | elapsed:   44.1s
# [Parallel(n_jobs=-1)]: Done  90 tasks      | elapsed:   50.7s
# [Parallel(n_jobs=-1)]: Done 105 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done 120 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=-1)]: Done 137 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=-1)]: Done 154 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=-1)]: Done 173 tasks      | elapsed:  1.9min
# [Parallel(n_jobs=-1)]: Done 192 tasks      | elapsed:  2.2min
# [Parallel(n_jobs=-1)]: Done 213 tasks      | elapsed:  2.5min
# [Parallel(n_jobs=-1)]: Done 234 tasks      | elapsed:  2.8min
# [Parallel(n_jobs=-1)]: Done 257 tasks      | elapsed:  3.1min
# [Parallel(n_jobs=-1)]: Done 280 tasks      | elapsed:  3.5min
# [Parallel(n_jobs=-1)]: Done 305 tasks      | elapsed:  3.7min
# [Parallel(n_jobs=-1)]: Done 330 tasks      | elapsed:  4.0min
# [Parallel(n_jobs=-1)]: Done 357 tasks      | elapsed:  4.2min
# [Parallel(n_jobs=-1)]: Done 384 tasks      | elapsed:  4.6min
# [Parallel(n_jobs=-1)]: Done 413 tasks      | elapsed:  4.9min
# [Parallel(n_jobs=-1)]: Done 442 tasks      | elapsed:  5.3min
# [Parallel(n_jobs=-1)]: Done 473 tasks      | elapsed:  5.7min
# [Parallel(n_jobs=-1)]: Done 504 tasks      | elapsed:  6.2min
# [Parallel(n_jobs=-1)]: Done 537 tasks      | elapsed:  6.7min
# [Parallel(n_jobs=-1)]: Done 570 tasks      | elapsed:  7.0min
# [Parallel(n_jobs=-1)]: Done 605 tasks      | elapsed:  7.3min
# [Parallel(n_jobs=-1)]: Done 640 tasks      | elapsed:  7.7min
# [Parallel(n_jobs=-1)]: Done 677 tasks      | elapsed:  8.2min
# [Parallel(n_jobs=-1)]: Done 714 tasks      | elapsed:  8.7min
# [Parallel(n_jobs=-1)]: Done 753 tasks      | elapsed:  9.2min
# [Parallel(n_jobs=-1)]: Done 792 tasks      | elapsed:  9.9min
# [Parallel(n_jobs=-1)]: Done 833 tasks      | elapsed: 10.4min
# [Parallel(n_jobs=-1)]: Done 874 tasks      | elapsed: 10.8min
# [Parallel(n_jobs=-1)]: Done 917 tasks      | elapsed: 11.3min
# [Parallel(n_jobs=-1)]: Done 960 tasks      | elapsed: 11.9min
# [Parallel(n_jobs=-1)]: Done 1005 tasks      | elapsed: 12.5min
# [Parallel(n_jobs=-1)]: Done 1050 tasks      | elapsed: 13.1min
# [Parallel(n_jobs=-1)]: Done 1097 tasks      | elapsed: 13.6min
# [Parallel(n_jobs=-1)]: Done 1144 tasks      | elapsed: 14.1min
# [Parallel(n_jobs=-1)]: Done 1193 tasks      | elapsed: 14.5min
# [Parallel(n_jobs=-1)]: Done 1242 tasks      | elapsed: 15.1min
# [Parallel(n_jobs=-1)]: Done 1293 tasks      | elapsed: 15.9min
# [Parallel(n_jobs=-1)]: Done 1344 tasks      | elapsed: 16.6min
# [Parallel(n_jobs=-1)]: Done 1397 tasks      | elapsed: 17.3min
# [Parallel(n_jobs=-1)]: Done 1450 tasks      | elapsed: 17.9min
# [Parallel(n_jobs=-1)]: Done 1505 tasks      | elapsed: 18.6min
# [Parallel(n_jobs=-1)]: Done 1560 tasks      | elapsed: 19.5min
# [Parallel(n_jobs=-1)]: Done 1617 tasks      | elapsed: 20.4min
# [Parallel(n_jobs=-1)]: Done 1674 tasks      | elapsed: 21.1min
# [Parallel(n_jobs=-1)]: Done 1733 tasks      | elapsed: 21.7min
# [Parallel(n_jobs=-1)]: Done 1792 tasks      | elapsed: 22.5min
# [Parallel(n_jobs=-1)]: Done 1853 tasks      | elapsed: 23.4min
# [Parallel(n_jobs=-1)]: Done 1914 tasks      | elapsed: 24.2min
# [Parallel(n_jobs=-1)]: Done 1977 tasks      | elapsed: 24.9min
# [Parallel(n_jobs=-1)]: Done 2040 tasks      | elapsed: 25.8min
# [Parallel(n_jobs=-1)]: Done 2105 tasks      | elapsed: 26.7min
# [Parallel(n_jobs=-1)]: Done 2170 tasks      | elapsed: 27.8min
# [Parallel(n_jobs=-1)]: Done 2237 tasks      | elapsed: 28.6min
# [Parallel(n_jobs=-1)]: Done 2304 tasks      | elapsed: 29.5min
# [Parallel(n_jobs=-1)]: Done 2373 tasks      | elapsed: 30.6min
# [Parallel(n_jobs=-1)]: Done 2442 tasks      | elapsed: 31.8min
# [Parallel(n_jobs=-1)]: Done 2513 tasks      | elapsed: 32.6min
# [Parallel(n_jobs=-1)]: Done 2584 tasks      | elapsed: 33.6min
# [Parallel(n_jobs=-1)]: Done 2657 tasks      | elapsed: 34.7min
# [Parallel(n_jobs=-1)]: Done 2730 tasks      | elapsed: 35.8min
# [Parallel(n_jobs=-1)]: Done 2805 tasks      | elapsed: 36.9min
# [Parallel(n_jobs=-1)]: Done 2880 tasks      | elapsed: 38.1min
# [Parallel(n_jobs=-1)]: Done 2957 tasks      | elapsed: 39.8min
# [Parallel(n_jobs=-1)]: Done 3034 tasks      | elapsed: 41.0min
# [Parallel(n_jobs=-1)]: Done 3113 tasks      | elapsed: 42.4min
# [Parallel(n_jobs=-1)]: Done 3192 tasks      | elapsed: 43.9min
# [Parallel(n_jobs=-1)]: Done 3273 tasks      | elapsed: 45.3min
# [Parallel(n_jobs=-1)]: Done 3354 tasks      | elapsed: 46.5min
# [Parallel(n_jobs=-1)]: Done 3437 tasks      | elapsed: 48.0min
# [Parallel(n_jobs=-1)]: Done 3520 tasks      | elapsed: 49.8min
# [Parallel(n_jobs=-1)]: Done 3605 tasks      | elapsed: 50.9min
# [Parallel(n_jobs=-1)]: Done 3690 tasks      | elapsed: 52.4min
# [Parallel(n_jobs=-1)]: Done 3777 tasks      | elapsed: 54.3min
# [Parallel(n_jobs=-1)]: Done 3864 tasks      | elapsed: 55.5min
# [Parallel(n_jobs=-1)]: Done 3953 tasks      | elapsed: 57.0min
# [Parallel(n_jobs=-1)]: Done 4042 tasks      | elapsed: 58.8min
# [Parallel(n_jobs=-1)]: Done 4050 out of 4050 | elapsed: 59.0min finished
# GridSearchCV(cv=10, error_score=nan,
#              estimator=XGBClassifier(base_score=None, booster=None,
#                                      colsample_bylevel=None,
#                                      colsample_bynode=None,
#                                      colsample_bytree=None, gamma=None,
#                                      gpu_id=None, importance_type='gain',
#                                      interaction_constraints=None,
#                                      learning_rate=0.02, max_delta_step=None,
#                                      max_depth=None, min_child_weight=None,
#                                      missing=nan, monotone_constraints=None,
#                                      n_esti...
#                                      reg_lambda=None, scale_pos_weight=None,
#                                      subsample=None, tree_method=None,
#                                      validate_parameters=None, verbosity=None),
#              iid='deprecated', n_jobs=-1,
#              param_grid={'colsample_bytree': [0.6, 0.8, 1.0],
#                          'gamma': [0.5, 1, 1.5, 2, 5], 'max_depth': [3, 4, 5],
#                          'min_child_weight': [1, 5, 10],
#                          'subsample': [0.6, 0.8, 1.0]},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=None, verbose=10)

# %%
y_train_predict_xgb_cv = gd_xgb.best_estimator_.predict(x_train)
y_test_predict_xgb_cv = gd_xgb.best_estimator_.predict(df_test)

# %%
classifcation_report_train_test(y_train, y_train_predict_xgb_cv)
# Out:
#             =========================================
#                CLASSIFICATION REPORT FOR TRAIN DATA
#             =========================================
#
#               precision    recall  f1-score   support
#
#            0       0.80      0.91      0.85      3827
#            1       0.68      0.46      0.55      1496
#            2       0.64      0.59      0.61       581
#
#     accuracy                           0.77      5904
#    macro avg       0.71      0.65      0.67      5904
# weighted avg       0.75      0.77      0.75      5904

# %%
# XgBoost with more parameters
model = XGBClassifier(random_state=1234)
gridParams = {
    'learning_rate': [0.005, 0.01,0.1,0.3],# shrinkage rate at which model learns
    'n_estimators': [50,100,150],# Number of gradient boosted trees. Equivalent to number of boosting rounds.
    'num_leaves': [6,8,12,16], # large num_leaves helps improve accuracy but might lead to over-fitting
    'boosting_type' : ['gbdt', 'dart'], # for better accuracy 
    'objective' : ['multi:softmax'],# mentioning objective as multiclass classification Model
    'max_bin':[255, 510], # large max_bin helps improve accuracy but might slow down training progress
    'random_state' : [500],# Random number seed.
    'colsample_bytree' : [0.64, 0.65, 0.66],# Subsample ratio of columns when constructing each tree.
    'subsample' : [0.7,0.75,0.8],# Subsample ratio of the training instance.
    'reg_alpha' : [1,1.2],# L1 regularization term on weights
    'reg_lambda' : [1,1.2,1.4],# L2 regularization term on weights
    'num_class' : [3],
    }
grid_xgb = GridSearchCV(model, gridParams, verbose=10, cv=5, n_jobs=-1)
grid_xgb.fit(x_train, y_train)
# Out:
# Fitting 5 folds for each of 10368 candidates, totalling 51840 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   5 tasks      | elapsed:    6.3s
# [Parallel(n_jobs=-1)]: Done  10 tasks      | elapsed:    7.2s
# [Parallel(n_jobs=-1)]: Done  17 tasks      | elapsed:    9.0s
# [Parallel(n_jobs=-1)]: Done  24 tasks      | elapsed:    9.9s
# [Parallel(n_jobs=-1)]: Done  33 tasks      | elapsed:   12.8s
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:   15.0s
# [Parallel(n_jobs=-1)]: Done  53 tasks      | elapsed:   17.6s
# [Parallel(n_jobs=-1)]: Done  64 tasks      | elapsed:   19.6s
# [Parallel(n_jobs=-1)]: Done  77 tasks      | elapsed:   22.9s
# [Parallel(n_jobs=-1)]: Done  90 tasks      | elapsed:   25.9s
# [Parallel(n_jobs=-1)]: Done 105 tasks      | elapsed:   29.4s
# [Parallel(n_jobs=-1)]: Done 120 tasks      | elapsed:   32.4s
# [Parallel(n_jobs=-1)]: Done 137 tasks      | elapsed:   36.6s
# [Parallel(n_jobs=-1)]: Done 154 tasks      | elapsed:   40.1s
# [Parallel(n_jobs=-1)]: Done 173 tasks      | elapsed:   44.5s
# [Parallel(n_jobs=-1)]: Done 192 tasks      | elapsed:   48.4s
# [Parallel(n_jobs=-1)]: Done 213 tasks      | elapsed:   53.3s
# [Parallel(n_jobs=-1)]: Done 234 tasks      | elapsed:   57.7s
# [Parallel(n_jobs=-1)]: Done 257 tasks      | elapsed:  1.0min
# [Parallel(n_jobs=-1)]: Done 280 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done 305 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=-1)]: Done 330 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 357 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=-1)]: Done 384 tasks      | elapsed:  1.7min
# [Parallel(n_jobs=-1)]: Done 413 tasks      | elapsed:  2.0min
# [Parallel(n_jobs=-1)]: Done 442 tasks      | elapsed:  2.2min
# [Parallel(n_jobs=-1)]: Done 473 tasks      | elapsed:  2.4min
# [Parallel(n_jobs=-1)]: Done 504 tasks      | elapsed:  2.6min
# [Parallel(n_jobs=-1)]: Done 537 tasks      | elapsed:  2.9min
# [Parallel(n_jobs=-1)]: Done 570 tasks      | elapsed:  3.1min
# [Parallel(n_jobs=-1)]: Done 605 tasks      | elapsed:  3.4min
# [Parallel(n_jobs=-1)]: Done 640 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=-1)]: Done 677 tasks      | elapsed:  3.9min
# [Parallel(n_jobs=-1)]: Done 714 tasks      | elapsed:  4.2min
# [Parallel(n_jobs=-1)]: Done 753 tasks      | elapsed:  4.6min
# [Parallel(n_jobs=-1)]: Done 792 tasks      | elapsed:  5.0min
# [Parallel(n_jobs=-1)]: Done 833 tasks      | elapsed:  5.4min
# [Parallel(n_jobs=-1)]: Done 874 tasks      | elapsed:  5.9min
# [Parallel(n_jobs=-1)]: Done 917 tasks      | elapsed:  6.4min
# [Parallel(n_jobs=-1)]: Done 960 tasks      | elapsed:  6.8min
# [Parallel(n_jobs=-1)]: Done 1005 tasks      | elapsed:  7.3min
# [Parallel(n_jobs=-1)]: Done 1050 tasks      | elapsed:  7.9min
# [Parallel(n_jobs=-1)]: Done 1097 tasks      | elapsed:  8.2min
# [Parallel(n_jobs=-1)]: Done 1144 tasks      | elapsed:  8.4min
# [Parallel(n_jobs=-1)]: Done 1193 tasks      | elapsed:  8.6min
# [Parallel(n_jobs=-1)]: Done 1242 tasks      | elapsed:  8.8min
# [Parallel(n_jobs=-1)]: Done 1293 tasks      | elapsed:  9.0min
# [Parallel(n_jobs=-1)]: Done 1344 tasks      | elapsed:  9.1min
# [Parallel(n_jobs=-1)]: Done 1397 tasks      | elapsed:  9.3min
# [Parallel(n_jobs=-1)]: Done 1450 tasks      | elapsed:  9.6min
# [Parallel(n_jobs=-1)]: Done 1505 tasks      | elapsed: 10.0min
# [Parallel(n_jobs=-1)]: Done 1560 tasks      | elapsed: 10.4min
# [Parallel(n_jobs=-1)]: Done 1617 tasks      | elapsed: 10.9min
# [Parallel(n_jobs=-1)]: Done 1674 tasks      | elapsed: 11.3min
# [Parallel(n_jobs=-1)]: Done 1733 tasks      | elapsed: 11.8min
# [Parallel(n_jobs=-1)]: Done 1792 tasks      | elapsed: 12.2min
# [Parallel(n_jobs=-1)]: Done 1853 tasks      | elapsed: 12.9min
# [Parallel(n_jobs=-1)]: Done 1914 tasks      | elapsed: 17.6min
# [Parallel(n_jobs=-1)]: Done 1977 tasks      | elapsed: 18.3min
# [Parallel(n_jobs=-1)]: Done 2040 tasks      | elapsed: 19.0min
# [Parallel(n_jobs=-1)]: Done 2105 tasks      | elapsed: 19.7min
# [Parallel(n_jobs=-1)]: Done 2170 tasks      | elapsed: 20.4min
# [Parallel(n_jobs=-1)]: Done 2237 tasks      | elapsed: 20.6min
# [Parallel(n_jobs=-1)]: Done 2304 tasks      | elapsed: 20.9min
# [Parallel(n_jobs=-1)]: Done 2373 tasks      | elapsed: 21.1min
# [Parallel(n_jobs=-1)]: Done 2442 tasks      | elapsed: 21.4min
# [Parallel(n_jobs=-1)]: Done 2513 tasks      | elapsed: 21.7min
# [Parallel(n_jobs
# [Parallel(n_jobs=-1)]: Done 48042 tasks      | elapsed: 591.8min
# [Parallel(n_jobs=-1)]: Done 48353 tasks      | elapsed: 594.6min
# [Parallel(n_jobs=-1)]: Done 48664 tasks      | elapsed: 597.6min
# [Parallel(n_jobs=-1)]: Done 48977 tasks      | elapsed: 598.8min
# [Parallel(n_jobs=-1)]: Done 49290 tasks      | elapsed: 603.5min
# [Parallel(n_jobs=-1)]: Done 49605 tasks      | elapsed: 606.8min
# [Parallel(n_jobs=-1)]: Done 49920 tasks      | elapsed: 608.5min
# [Parallel(n_jobs=-1)]: Done 50237 tasks      | elapsed: 610.7min
# [Parallel(n_jobs=-1)]: Done 50554 tasks      | elapsed: 613.7min
# [Parallel(n_jobs=-1)]: Done 50873 tasks      | elapsed: 616.7min
# [Parallel(n_jobs=-1)]: Done 51192 tasks      | elapsed: 618.2min
# [Parallel(n_jobs=-1)]: Done 51513 tasks      | elapsed: 620.8min
# [Parallel(n_jobs=-1)]: Done 51840 out of 51840 | elapsed: 624.6min finished
# [13:34:35] WARNING: /Users/travis/build/dmlc/xgboost/src/learner.cc:480:
# Parameters: { boosting_type, num_leaves } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
# GridSearchCV(cv=5, error_score=nan,
#              estimator=XGBClassifier(base_score=None, booster=None,
#                                      colsample_bylevel=None,
#                                      colsample_bynode=None,
#                                      colsample_bytree=None, gamma=None,
#                                      gpu_id=None, importance_type='gain',
#                                      interaction_constraints=None,
#                                      learning_rate=None, max_delta_step=None,
#                                      max_depth=None, min_child_weight=None,
#                                      missing=nan, monotone_constraints=None,
#                                      n_estim...
#                          'colsample_bytree': [0.64, 0.65, 0.66],
#                          'learning_rate': [0.005, 0.01, 0.1, 0.3],
#                          'max_bin': [255, 510], 'n_estimators': [50, 100, 150],
#                          'num_class': [3], 'num_leaves': [6, 8, 12, 16],
#                          'objective': ['multi:softmax'], 'random_state': [500],
#                          'reg_alpha': [1, 1.2], 'reg_lambda': [1, 1.2, 1.4],
#                          'subsample': [0.7, 0.75, 0.8]},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=None, verbose=10)

# %%
y_train_xgb_pm = grid_xgb.best_estimator_.predict(x_train)
y_test_xgb_pm = grid_xgb.best_estimator_.predict(df_test)

# %%
classifcation_report_train_test(y_train, y_train_xgb_pm)
# Out:
#             =========================================
#                CLASSIFICATION REPORT FOR TRAIN DATA
#             =========================================
#
#               precision    recall  f1-score   support
#
#            0       0.90      0.94      0.92      3827
#            1       0.83      0.74      0.78      1496
#            2       0.81      0.78      0.80       581
#
#     accuracy                           0.88      5904
#    macro avg       0.85      0.82      0.83      5904
# weighted avg       0.87      0.88      0.87      5904

# %%
y_test_xgb_cv_pm = df_test.copy()
y_test_xgb_cv_pm["downtime_duration"] = y_test_xgb_pm

# %%
y_test_xgb_cv_pm.drop(["factory_number", "issue_type", "assembly_line_type", "car_variant",
                   "log_report_type", "volume"], axis=1, inplace = True)

# %%
y_test_xgb_cv_pm.head()
# Out:
#       id  downtime_duration
# 0   3340                  0
# 1  14067                  0
# 2   1134                  2
# 3     27                  0
# 4   9793                  0

# %%
y_test_xgb_cv_pm.to_csv("y_test_xgb_cv_pm.csv", sep=",", index=False)

# %% [markdown]
# # Further Suggestion

# %% [markdown]
# In This Data set we have an indirect mapping between id, assembly_line_type, car_variant and log_report_type. if we had a direct mapping, our data would have been more granular and the models would have made better predictions . For Example we don't have a mapping like what all car_variant are there for a particular assembly_line_type or what all log_report_type are there for a car_variant
#
# if we had such a data with direct mapping, we can improve the model predictions
#
# With time constraint at hand, I wasn't able to improve it further, but Another approach that can help n improving the model further is by adding counts of assembly_line_type, Car_variant, log_report_type with respect to each id. Adding these features, I believe will improve the model further.
